# %%
import pandas as pd

# %%
NaN_counts = pd.read_csv('data/season_1/training_data/order_data/NaN_counts/NaN.csv')

# %%
NaN_counts
# Out:
#               date               start_district_hash  time_slice  order_id  \
# 0       2016-01-01  08232402614a9b48895cc3d0aeb0e9f2           6         2
# 1       2016-01-01  08232402614a9b48895cc3d0aeb0e9f2           7         1
# 2       2016-01-01  08232402614a9b48895cc3d0aeb0e9f2          15         1
# 3       2016-01-01  08232402614a9b48895cc3d0aeb0e9f2          16         1
# 4       2016-01-01  08232402614a9b48895cc3d0aeb0e9f2          27         1
# 5       2016-01-01  08232402614a9b48895cc3d0aeb0e9f2          31         1
# 6       2016-01-01  08232402614a9b48895cc3d0aeb0e9f2          34         1
# 7       2016-01-01  08232402614a9b48895cc3d0aeb0e9f2          39         1
# 8       2016-01-01  08232402614a9b48895cc3d0aeb0e9f2          40         1
# 9       2016-01-01  08232402614a9b48895cc3d0aeb0e9f2          48         1
# 10      2016-01-01  08232402614a9b48895cc3d0aeb0e9f2          54         1
# ...

# %%
train_filtered = NaN_counts[NaN_counts['time_slice'].isin([46,58,70,82,94,106,118,130,142])]

# %%
train_filtered
# Out:
#               date               start_district_hash  time_slice  order_id  \
# 13      2016-01-01  08232402614a9b48895cc3d0aeb0e9f2          58         1
# 22      2016-01-01  08232402614a9b48895cc3d0aeb0e9f2          70         1
# 30      2016-01-01  08232402614a9b48895cc3d0aeb0e9f2          82         1
# 37      2016-01-01  08232402614a9b48895cc3d0aeb0e9f2          94         1
# 40      2016-01-01  08232402614a9b48895cc3d0aeb0e9f2         106         1
# 50      2016-01-01  08232402614a9b48895cc3d0aeb0e9f2         142         1
# 62      2016-01-01  08f5b445ec6b29deba62e6fd8b0325a6          46         2
# 75      2016-01-01  08f5b445ec6b29deba62e6fd8b0325a6          70         3
# 82      2016-01-01  08f5b445ec6b29deba62e6fd8b0325a6          82         2
# 94      2016-01-01  08f5b445ec6b29deba62e6fd8b0325a6          94         6
# 179     2016-01-01  1afd7afbc81ecc1b13886a569d869e8a          46       129
# ...

# %%
train_filtered.iloc[:, :4].to_csv('train_filtered_all.csv')
