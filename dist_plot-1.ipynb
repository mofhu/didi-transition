# %%
import pandas as pd

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_csv("data/season_1/groupby_all.csv")

# %%
df.dtypes
# Out:
# start_district_num    object
# time_slice            object
# date                  object
# order_count           object
# succeed_count         object
# gap                   object
# dtype: object

# %%
df[["start_district_num", "order_count", 'succeed_count', 'gap']] = df[["start_district_num", "order_count", 'succeed_count', 'gap']].\
    apply(lambda x: pd.to_numeric(x, errors='coerce'))

# %%
df.dtypes
# Out:
# start_district_num    float64
# time_slice             object
# date                   object
# order_count           float64
# succeed_count         float64
# gap                   float64
# dtype: object

# %%
dist_id = 1

# %%
df_dist = df.loc[df['start_district_num'] == dist_id]

# %%
df_dist
# Out:
#         start_district_num time_slice          date  order_count  \
# 0                      1.0          1    2016-01-01        187.0
# 1                      1.0          2    2016-01-01        198.0
# 2                      1.0          3    2016-01-01        192.0
# 3                      1.0          4    2016-01-01        172.0
# 4                      1.0          5    2016-01-01        153.0
# 5                      1.0          6    2016-01-01        132.0
# 6                      1.0          7    2016-01-01        133.0
# 7                      1.0          8    2016-01-01        130.0
# 8                      1.0          9    2016-01-01        120.0
# 9                      1.0         10    2016-01-01        111.0
# 10                     1.0         11    2016-01-01         72.0
# 11                     1.0         12    2016-01-01         73.0
# 12                     1.0         13    2016-01-01         61.0
# ...

# %%
df_dist.groupby('date').sum()
# Out:
#               start_district_num  order_count  succeed_count     gap
# date
# 1-2016-01-22               144.0       5370.0         5216.0   154.0
# 1-2016-01-24               144.0       4902.0         4770.0   132.0
# 1-2016-01-26               144.0       4380.0         4233.0   147.0
# 1-2016-01-28               144.0       4457.0         4285.0   172.0
# 1-2016-01-30               144.0       4372.0         4173.0   199.0
# 2016-01-01                 144.0      25557.0        23185.0  2372.0
# 2016-01-02                 144.0      18024.0        17404.0   620.0
# 2016-01-03                 144.0      19159.0        18569.0   590.0
# 2016-01-04                 144.0      20801.0        20107.0   694.0
# 2016-01-05                 144.0      21997.0        21134.0   863.0
# 2016-01-06                 144.0      21702.0        20717.0   985.0
# 2016-01-07                 144.0      19756.0        19154.0   602.0
# ...

# %%
df_dist.groupby('date').sum().plot()

# %%
df_dist['time_slice'] = df['time_slice'].\
    apply(lambda x: pd.to_numeric(x, errors='coerce'))
# Out:
# /Users/mofrankhu/.pyenv/versions/3.5.1/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
train_dates = []
for i in range(1, 22):
    if i < 10:
        train_dates.append('2016-01-0' + str(i))
    else:
        train_dates.append('2016-01-' + str(i))
print(train_dates)
df_dist.loc[df['date'].isin(train_dates)].groupby('time_slice').sum()
# Out:
# ['2016-01-01', '2016-01-02', '2016-01-03', '2016-01-04', '2016-01-05', '2016-01-06', '2016-01-07', '2016-01-08', '2016-01-09', '2016-01-10', '2016-01-11', '2016-01-12', '2016-01-13', '2016-01-14', '2016-01-15', '2016-01-16', '2016-01-17', '2016-01-18', '2016-01-19', '2016-01-20', '2016-01-21']
#             start_district_num  order_count  succeed_count    gap
# time_slice
# 1.0                       21.0       1625.0         1492.0  133.0
# 2.0                       21.0       1395.0         1286.0  109.0
# 3.0                       21.0       1285.0         1190.0   95.0
# 4.0                       21.0       1150.0         1088.0   62.0
# 5.0                       21.0       1083.0         1029.0   54.0
# 6.0                       21.0        972.0          923.0   49.0
# 7.0                       21.0        911.0          850.0   61.0
# 8.0                       21.0        833.0          775.0   58.0
# 9.0                       21.0        805.0          743.0   62.0
# ...

# %%
df_dist.loc[df['date'].isin(train_dates)].groupby('time_slice').sum().plot();
plt.legend(loc='best');

# %%
df_dist.sort_values(by="gap",ascending=False)
# Out:
#         start_district_num  time_slice          date  order_count  \
# 95099                  1.0        50.0    2016-01-11        716.0
# 190149                 1.0        50.0    2016-01-21        622.0
# 39                     1.0        40.0    2016-01-01        295.0
# 37                     1.0        38.0    2016-01-01        239.0
# 190152                 1.0        53.0    2016-01-21        610.0
# 38                     1.0        39.0    2016-01-01        240.0
# 36                     1.0        37.0    2016-01-01        227.0
# 190150                 1.0        51.0    2016-01-21        549.0
# 95102                  1.0        53.0    2016-01-11        617.0
# 40                     1.0        41.0    2016-01-01        246.0
# 142708                 1.0       134.0    2016-01-16        453.0
# 190148                 1.0        49.0    2016-01-21        512.0
# 95101                  1.0        52.0    2016-01-11        561.0
# ...

# %%
df_sort_gap = df_dist.sort_values(by="gap",ascending=False)

# %%
df_sort_gap['x'] = list(range(0,len(df_sort_gap['gap'])))

# %%
df_sort_gap.plot(x='x',y='gap')
